# %%
import read_chn as rc
import matplotlib.pyplot as plt
# %config InlineBackend.figure_format='retina'

# %%
spec_obj = rc.gamma_data('gamma_spectrum.Chn')
spec_obj.hist_array
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
plt.plot(spec_obj.hist_array)
